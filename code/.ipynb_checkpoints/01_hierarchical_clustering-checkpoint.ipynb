# %%
import sys
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.stats import pearsonr

pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)

# %% [markdown]
# ## Read data

# %%
## параметры чтения
CASE_NAME = "case3"
FILE_NAME = "raw_data.xlsx"

SHEET_NAME = "Критерии + рез по группам"

# %%
columns_to_drop = [
    "Sample", "Expression SEM", "Target", 
    "Mean Cq", "Mean Efficiency Corrected Cq", "Normalized Expression", "Expression SEM", "Regulation", 
    "Target.1", 'Unnamed: 33', 'Unnamed: 34', 'группа/критерий', 'N of motifs.1',
       'N of all G4-seqs.1', 'N of rel G4-seqs.1', 'N of BG4.1',
       'Max score of BG4.1', 'Max score of G4-seqs.1',
       'Max score of rel G4 seqs.1', 'ENH: N of all G4-seqs.1',
       'ENH: N of BG4.1', 'ENH: freq of all G4-seqs.1', 'ENH:freq of BG4.1',
       'ENH: rank.1', 'score YY1.1', 'score pol2.1', 'score c-myc.1',
       'score CTCF.1', 'score SP1.1', 'score MAZ.1', 'N of YY1.1',
       'N of  pol2.1', 'N of c-myc.1', 'N of  CTCF.1', 'N of SP1.1',
       'N of MAZ.1'
]

raw_data = (
    pd.read_excel(f"../data/{CASE_NAME}/{FILE_NAME}", sheet_name=SHEET_NAME)
    .drop(columns=columns_to_drop)
)
data_transposed = raw_data.T
raw_data.shape, data_transposed.shape
# Out:
# ((20, 25), (25, 20))

# %%
raw_data.columns
# Out:
# Index(['Relative Normalized Expression', 'N of motifs', 'N of all G4-seqs',
#        'N of rel G4-seqs', 'N of BG4', 'Max score of BG4',
#        'Max score of G4-seqs', 'Max score of rel G4 seqs',
#        'ENH: N of all G4-seqs', 'ENH: N of BG4', 'ENH: freq of all G4-seqs',
#        'ENH:freq of BG4', 'ENH: rank', 'score YY1', 'score pol2',
#        'score c-myc', 'score CTCF', 'score SP1', 'score MAZ', 'N of YY1',
#        'N of  pol2', 'N of c-myc', 'N of  CTCF', 'N of SP1', 'N of MAZ'],
#       dtype='object')

# %% [markdown]
# ## Clustering and dendrogramm

# %%
def metric_function_abs(x, y):
    return 1 - abs(pearsonr(x, y)[0])

def metric_function_with_sign(x, y):
    return 1 - pearsonr(x, y)[0]

# %% [markdown]
# ### 1) metric_function_abs

# %%
#?linkage

# %%
plt.figure(figsize=(8, 6))

linkage_data = linkage(data_transposed, method='complete', metric=metric_function_abs)
data_dendrogram_abs = dendrogram(linkage_data, orientation="left", leaf_label_func=lambda i: list(data_transposed.index)[i])

plt.savefig(f"../data/{CASE_NAME}/dendrogram_abs.png")
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(8, 8))
ordered_cols = data_dendrogram_abs["ivl"][::-1]
df_corr = raw_data[ordered_cols].corr()
img = ax.imshow(df_corr, interpolation='nearest', cmap='bwr')

ax.set_xticks([])
ax.set_yticklabels([])
ax.set_yticks(list(range(len(df_corr.columns))))
ax.set_yticklabels(list(df_corr.columns))

fig.colorbar(img)
plt.savefig(f"../data/{CASE_NAME}/matrix_abs.png")
plt.show()

# %% [markdown]
# ### 2) metric_function_with_sign

# %%
plt.figure(figsize=(8, 6))

linkage_data = linkage(data_transposed, method='complete', metric=metric_function_with_sign)
data_dendrogram_with_sign = dendrogram(linkage_data, orientation="left", leaf_label_func=lambda i: list(data_transposed.index)[i])

plt.savefig(f"../data/{CASE_NAME}/dendrogram_with_sign.png")
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(8, 8))
ordered_cols = data_dendrogram_with_sign["ivl"][::-1]
df_corr = raw_data[ordered_cols].corr()
img = ax.imshow(df_corr, interpolation='nearest', cmap='bwr')

ax.set_xticks([])
ax.set_yticklabels([])
ax.set_yticks(list(range(len(df_corr.columns))))
ax.set_yticklabels(list(df_corr.columns))

fig.colorbar(img)
plt.savefig(f"../data/{CASE_NAME}/matrix_with_sign.png")
plt.show()
